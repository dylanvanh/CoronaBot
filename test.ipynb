# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from datetime import date,timedelta

# %%
data = 'https://covid.ourworldindata.org/data/owid-covid-data.csv' #download the csv file
df = pd.read_csv(data) #read the csv file
df['date'] = pd.to_datetime(df.date) #convert the data
df.fillna(0)
# Out:
#       iso_code continent     location       date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan 2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan 2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan 2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan 2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan 2020-02-28          1.0        0.0
# ...        ...       ...          ...        ...          ...        ...
# 86891      ZWE    Africa     Zimbabwe 2021-05-04      38327.0       34.0
# 86892      ZWE    Africa     Zimbabwe 2021-05-05      38357.0       30.0
# 86893      ZWE    Africa     Zimbabwe 2021-05-06      38398.0       41.0
# 86894      ZWE    Africa     Zimbabwe 2021-05-07      38403.0        5.0
# 86895      ZWE    Africa     Zimbabwe 2021-05-08      38414.0       11.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
za = df[df['location'] == 'South Africa'] # '{country} , user inputted country stats are shown , get input from user
latest_info = za.iloc[-1] #last day in the dataset
previous_day = za.iloc[-2] #2nd last day in the dataset


za.date
za.tail(5) #see if the data is correct

from dateutil.parser import parse

'''
2 - Location
3 - Date`
4 - total cases
5 - new cases
6 - total deaths
7 - new deaths
34- total vaccinations
37 - new vaccinations
'''
# print(latest_info[4].astype(str) + 'hello')
# previous_day
# output = 'Location = za\n total cases =' + latest_info[3].astype(str)
yes = latest_info[3].strftime('%Y-%m-%d')

print(type(yes))
# Out:
# <class 'str'>

# %%
fig , ax = plt.subplots(figsize=(12,6))
ax.ticklabel_format(style='plain')

ax.plot(za.date,za.new_cases_smoothed,'b')

ax.set_title('New Cases in South Africa')
ax.set_ylabel('Amount of Cases')
ax.set_xlabel('Date')
ax.legend(['New Cases'])

from datetime import datetime,timedelta #program kept forgetting import just doing incase
date = datetime.now()
date = str(date)
date = date.strip()
date = date.replace(':','-')
plt.savefig('covid_graph'+date+'.png') #saves file

# %%
za2 = df[df['location'] == 'South Africa'] # if question is for South Africa
country_df = df[df['location'] == 'South Africa']
# Out:
# 71752   2020-02-07
# 71753   2020-02-08
# 71754   2020-02-09
# 71755   2020-02-10
# 71756   2020-02-11
#            ...
# 72204   2021-05-04
# 72205   2021-05-05
# 72206   2021-05-06
# 72207   2021-05-07
# 72208   2021-05-08
# Name: date, Length: 457, dtype: datetime64[ns]

# %%
fig , ax = plt.subplots(figsize=(12,6))
ax.ticklabel_format(style='plain')

ax.plot(za.date,za.new_cases_smoothed,'b')

ax.set_title('New Cases in South Africa')
ax.set_ylabel('Amount of Cases')
ax.set_xlabel('Date')
ax.legend(['New Cases'])

from datetime import datetime,timedelta #program kept forgetting import just doing incase
date = datetime.now()
date = str(date)
date = date.strip()
date = date.replace(':','-')
plt.savefig('covid_graph'+date+'.png') #saves file
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-b3f598f1b182> in <module>
#       3 ax.ticklabel_format(style='plain')
#       4 ax.plot(country_df.date,country_df.new_cases_smoothed,'b')
# ----> 5 ax.set_title('New Cases in','South')
#       6 ax.set_ylabel('Amount of Cases')
#       7 ax.set_xlabel('Date')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_axes.py in set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     165         title.update(default)
#     166         if fontdict is not None:
# --> 167             title.update(fontdict)
#     168         title.update(kwargs)
#     169         return title
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\text.py in update(self, kwargs)
#     174         # docstring inherited
#     175         # make a copy so we do not mutate user input!
# ...

# %%
za2['date'].head(1)
# Out:
# 71165   2020-02-07
# Name: date, dtype: datetime64[ns]

# %%
za2['date'] = pd.to_datetime(df['date'], unit='s')
# Out:
# <ipython-input-7-8f08357aa7c4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   za2['date'] = pd.to_datetime(df['date'], unit='s')

# %%
date = za2['date'].iloc[-1]
datenew = (date.today()+ timedelta(days=-1)).replace(hour=0, minute=0, second=0, microsecond=0)#yesterday


print(datenew)
print(date)

print(datenew == date)
# Out:
# 2021-05-05 00:00:00
# 2021-05-05 00:00:00
# True

# %%
def calc_dif_new_cases():
   #comapres the 2 days cases
    #if previous day cases are more :)) , cases gone down
    #if current day is more :((() , cases gone up
    
    cases_today = za2['new_cases'].iloc[-1] #last in df
    cases_yesterday = za2['new_cases'].iloc[-2] #second last in df
    

    if (cases_today - cases_yesterday) > 0:
        return 'More',cases_today
        #more cases today , as there is a positive value
    else:
        return "Less",cases_today

   
    return new_cases
