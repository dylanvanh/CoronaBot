# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from datetime import date,timedelta

# %%
data = 'https://covid.ourworldindata.org/data/owid-covid-data.csv' #download the csv file
df = pd.read_csv(data) #read the csv file
df['date'] = pd.to_datetime(df.date) #convert the data
df.fillna(0)
# Out:
#       iso_code continent     location       date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan 2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan 2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan 2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan 2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan 2020-02-28          1.0        0.0
# ...        ...       ...          ...        ...          ...        ...
# 86452      ZWE    Africa     Zimbabwe 2021-05-02      38281.0       21.0
# 86453      ZWE    Africa     Zimbabwe 2021-05-03      38293.0       12.0
# 86454      ZWE    Africa     Zimbabwe 2021-05-04      38327.0       34.0
# 86455      ZWE    Africa     Zimbabwe 2021-05-05      38357.0       30.0
# 86456      ZWE    Africa     Zimbabwe 2021-05-06      38398.0       41.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                   0.000           0.0         0.0                0.000  ...
# 1                   0.000           0.0         0.0                0.000  ...
# 2                   0.000           0.0         0.0                0.000  ...
# 3                   0.000           0.0         0.0                0.000  ...
# 4                   0.000           0.0         0.0                0.000  ...
# ...                   ...           ...         ...                  ...  ...
# 86452              27.857        1570.0         2.0                1.857  ...
# 86453              27.286        1573.0         3.0                1.857  ...
# 86454              23.286        1574.0         1.0                1.286  ...
# 86455              23.714        1574.0         0.0                1.286  ...
# 86456              23.286        1575.0         1.0                1.143  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              0.0                597.029
# 1            1803.987              0.0                597.029
# 2            1803.987              0.0                597.029
# 3            1803.987              0.0                597.029
# 4            1803.987              0.0                597.029
# ...               ...              ...                    ...
# 86452        1899.775             21.4                307.846
# 86453        1899.775             21.4                307.846
# 86454        1899.775             21.4                307.846
# 86455        1899.775             21.4                307.846
# 86456        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             0.0           0.0
# 1                     9.59             0.0           0.0
# 2                     9.59             0.0           0.0
# 3                     9.59             0.0           0.0
# 4                     9.59             0.0           0.0
# ...                    ...             ...           ...
# 86452                 1.82             1.6          30.7
# 86453                 1.82             1.6          30.7
# 86454                 1.82             1.6          30.7
# 86455                 1.82             1.6          30.7
# 86456                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 86452                  36.791                         1.7            61.49
# 86453                  36.791                         1.7            61.49
# 86454                  36.791                         1.7            61.49
# 86455                  36.791                         1.7            61.49
# 86456                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 86452                    0.571
# 86453                    0.571
# 86454                    0.571
# 86455                    0.571
# 86456                    0.571
#
# [86457 rows x 59 columns]

# %%
za = df[df['location'] == 'South Africa'] # '{country} , user inputted country stats are shown , get input from user
latest_info = za.iloc[-1] #last day in the dataset
previous_day = za.iloc[-2] #2nd last day in the dataset


za.tail(5) #see if the data is correct


'''
2 - Location
3 - Date
4 - total cases
5 - new cases
6 - total deaths
7 - new deaths
34- total vaccinations
37 - new vaccinations
'''
# latest_info
# previous_day
# Out:
# iso_code                                                 ZAF
# continent                                             Africa
# location                                        South Africa
# date                                     2021-05-05 00:00:00
# total_cases                                        1588221.0
# new_cases                                             2073.0
# new_cases_smoothed                                  1395.857
# total_deaths                                         54557.0
# new_deaths                                              46.0
# new_deaths_smoothed                                   38.857
# total_cases_per_million                            26778.892
# new_cases_per_million                                 34.953
# new_cases_smoothed_per_million                        23.535
# total_deaths_per_million                             919.882
# new_deaths_per_million                                 0.776
# new_deaths_smoothed_per_million                        0.655
# reproduction_rate                                       1.23
# icu_patients                                             NaN
# icu_patients_per_million                                 NaN
# hosp_patients                                            NaN
# hosp_patients_per_million                                NaN
# weekly_icu_admissions                                    NaN
# weekly_icu_admissions_per_million                        NaN
# weekly_hosp_admissions                                   NaN
# weekly_hosp_admissions_per_million                       NaN
# new_tests                                            33414.0
# total_tests                                       10773227.0
# total_tests_per_thousand                             181.647
# new_tests_per_thousand                                 0.563
# new_tests_smoothed                                   26160.0
# new_tests_smoothed_per_thousand                        0.441
# positive_rate                                          0.053
# tests_per_case                                          18.7
# tests_units                                    people tested
# total_vaccinations                                  366101.0
# people_vaccinated                                   366101.0
# people_fully_vaccinated                             366101.0
# new_vaccinations                                     12920.0
# new_vaccinations_smoothed                             9707.0
# total_vaccinations_per_hundred                          0.62
# people_vaccinated_per_hundred                           0.62
# people_fully_vaccinated_per_hundred                     0.62
# new_vaccinations_smoothed_per_million                  164.0
# stringency_index                                         NaN
# population                                        59308690.0
# population_density                                    46.754
# median_age                                              27.3
# aged_65_older                                          5.344
# aged_70_older                                          3.053
# gdp_per_capita                                     12294.876
# extreme_poverty                                         18.9
# cardiovasc_death_rate                                 200.38
# diabetes_prevalence                                     5.52
# female_smokers                                           8.1
# male_smokers                                            33.2
# handwashing_facilities                                43.993
# hospital_beds_per_thousand                              2.32
# life_expectancy                                        64.13
# human_development_index                                0.709
# Name: 71838, dtype: object

# %%
fig , ax = plt.subplots(figsize=(12,6))
ax.ticklabel_format(style='plain')

ax.plot(za.date,za.new_cases_smoothed,'b')

ax.set_title('New Cases in South Africa')
ax.set_ylabel('Amount of Cases')
ax.set_xlabel('Date')
ax.legend(['New Cases'])

from datetime import datetime,timedelta #program kept forgetting import just doing incase
date = datetime.now()
date = str(date)
date = date.strip()
date = date.replace(':','-')
plt.savefig('covid_graph'+date+'.png') #saves file
return 'covid_graph'+date+'.png' #filename
# Out:
# 2021-05-06 18-16-23.042840

# %%
za2 = df[df['location'] == 'South Africa'] # if question is for South Africa

# %%
za2['date'].head(1)
# Out:
# 71165   2020-02-07
# Name: date, dtype: datetime64[ns]

# %%
za2['date'] = pd.to_datetime(df['date'], unit='s')
# Out:
# <ipython-input-7-8f08357aa7c4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   za2['date'] = pd.to_datetime(df['date'], unit='s')

# %%
date = za2['date'].iloc[-1]
datenew = (date.today()+ timedelta(days=-1)).replace(hour=0, minute=0, second=0, microsecond=0)#yesterday


print(datenew)
print(date)

print(datenew == date)
# Out:
# 2021-05-05 00:00:00
# 2021-05-05 00:00:00
# True

# %%
def calc_dif_new_cases():
   #comapres the 2 days cases
    #if previous day cases are more :)) , cases gone down
    #if current day is more :((() , cases gone up
    
    cases_today = za2['new_cases'].iloc[-1] #last in df
    cases_yesterday = za2['new_cases'].iloc[-2] #second last in df
    

    if (cases_today - cases_yesterday) > 0:
        return 'More',cases_today
        #more cases today , as there is a positive value
    else:
        return "Less",cases_today

   
    return new_cases
